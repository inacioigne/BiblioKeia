# %%
import httpx

# %%
url = 'https://id.loc.gov/authorities/names/suggest2/?q=Machado&count=25'
r = httpx.get(url)
r
# Out:
# <Response [200 OK]>

# %%
r.json()
# Out:
# {'q': 'Machado',
#  'count': 25,
#  'pagesize': 25,
#  'start': 1,
#  'sortmethod': 'alpha',
#  'searchtype': 'left-anchored',
#  'directory': '/authorities/names/',
#  'hits': [{'suggestLabel': 'Machado',
#    'uri': 'http://id.loc.gov/authorities/names/n78006087',
#    'aLabel': 'Machado',
#    'vLabel': '',
#    'code': '',
#    'rank': ''},
#   {'suggestLabel': 'Machado (Minas Gerais, Brazil)',
#    'uri': 'http://id.loc.gov/authorities/names/n86001174',
#    'aLabel': 'Machado (Minas Gerais, Brazil)',
#    'vLabel': '',
#    'code': '',
#    'rank': ''},
#   {'suggestLabel': 'Machado Aguiar, Pedro Adolfo, 1962-',
#    'uri': 'http://id.loc.gov/authorities/names/no2009156134',
#    'aLabel': 'Machado Aguiar, Pedro Adolfo, 1962-',
#    'vLabel': '',
#    'code': '',
#    'rank': ''},
#   {'suggestLabel': 'Machado Alfonso, Gerardo',
#    'uri': 'http://id.loc.gov/authorities/names/no2011070333',
#    'aLabel': 'Machado Alfonso, Gerardo',
#    'vLabel': '',
#    'code': '',
# ...
